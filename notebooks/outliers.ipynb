# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0,rpath)
from src.preprocessing import PreProcess
from src.overview import Overview
from src.outlier import Outlier
from src.plots import Plot

# %%
df = pd.read_csv('../data/uncleanData.csv')

# %%
#df2 = pd.read_excel("../data/Week1_challenge_data_source.xlsx")

# %%
outlier = Outlier(df)

# %%
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
df.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
#        'Nb of sec with 6250B < Vol UL < 37500B',
#        'Nb of sec with Vol DL < 6250B', 'Nb of sec with Vol UL < 1250B',
#        'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
#        'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)',
#        'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
#        'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)',
#        'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)',
#        'Total UL (Bytes)', 'Total DL (Bytes)'],
#       dtype='object')

# %% [markdown]
# Initialize plot class

# %%
pl = Plot()

# %%
# dfdfsdsdsdklkjjkjkjjkklkkjjikjjkjkjkjjkkjjfkldklkldfkldfdfdfdffddffpl.plot_box(df, 'nb_of_sec_with_vol_ul_<_1250b', 'Number of seconds with IP Volume DL < 1250B')

# %%
pl.plot_box(df, 'Dur. (ms)', 'Total Duration of the xDR (in ms)')

# %%
pl.plot_box(df, 'Avg RTT DL (ms)', 'Average Round Trip Time measurement Downlink direction (msecond)')

# %%
pl.plot_box(df, 'TCP UL Retrans. Vol (Bytes)', 'TCP volume of Uplink packets detected as retransmitted (bytes)')

# %%
pl.plot_box(df, 'Activity Duration UL (ms)', 'Activity duration ul(ms)')

# %%
pl.plot_box(df, 'Youtube UL (Bytes)', 'YouTube data volume (in Bytes) sent by the MS during this session')

# %%
pl.plot_box(df, 'Total UL (Bytes)', 'Total DL (Bytes)Data volume (in Bytes) received by the MS during this session (IP layer + overhead)')

# %%
pl.plot_box(df, 'Total DL (Bytes)', 'Total UL (Bytes)Data volume (in Bytes) sent by the MS during this session (IP layer + overhead)')

# %% [markdown]
# It can be seen that most of the column have outliers

# %% [markdown]
# Get Outlier overview

# %%
display(outlier.outlier_overview(df, 'Activity Duration UL (ms)'))
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 38      7.277826e+18  4/18/2019 15:40     982.0  4/25/2019 15:40    33.0
# 538     7.277826e+18  4/23/2019 23:45     419.0  4/24/2019 23:45   313.0
# 557     1.304243e+19  4/23/2019 23:56     766.0  4/24/2019 23:56   385.0
# 635     1.304243e+19   4/24/2019 0:09     773.0   4/25/2019 0:09   678.0
# 655     7.277826e+18   4/24/2019 0:11     540.0   4/25/2019 0:11   513.0
# ...              ...              ...       ...              ...     ...
# 148408  1.304243e+19   4/29/2019 7:09     731.0   4/30/2019 7:09   745.0
# 148994  1.304243e+19   4/29/2019 7:16     675.0   4/30/2019 7:16   689.0
# 148998  7.277826e+18   4/29/2019 7:16     452.0   4/30/2019 7:16   469.0
# 149014  1.304243e+19   4/29/2019 7:17     752.0   4/30/2019 7:17   596.0
# 150000           NaN              NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 38       604800.0  2.082095e+14   3.376394e+10  8.616400e+13
# 538       86399.0  2.082017e+14   3.366726e+10  8.637690e+13
# 557       86400.0  2.082017e+14   3.366344e+10  8.637690e+13
# 635       86399.0  2.082015e+14   3.366045e+10  8.637690e+13
# 655       86399.0  2.082017e+14   3.365830e+10  3.520271e+13
# ...           ...           ...            ...           ...
# 148408    86400.0  2.082017e+14   3.366057e+10  8.637690e+13
# 148994    86400.0  2.082018e+14   3.366725e+10  8.637690e+13
# 148998    86400.0  2.082017e+14   3.376216e+10  8.637690e+13
# 149014    86399.0  2.082018e+14   3.369922e+10  8.637690e+13
# 150000        NaN           NaN            NaN           NaN
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 38                T86868A  ...        2.167931e+07        1.650808e+07
# 538               D84798A  ...        1.544461e+07        6.669529e+06
# 557               D83916A  ...        1.622089e+07        1.592857e+07
# 635               D92712B  ...        2.052971e+07        1.582063e+07
# 655               K14666C  ...        2.504633e+06        3.938252e+06
# ...                   ...  ...                 ...                 ...
# 148408            T85784A  ...        1.226494e+07        1.357151e+06
# 148994            D85941B  ...        1.620507e+07        2.013526e+07
# 148998            T78199C  ...        1.618998e+07        1.971946e+07
# 149014            D93141C  ...        1.101610e+07        2.003353e+06
# 150000                NaN  ...        1.163407e+07        1.100941e+07
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 38            2.324310e+07        6.438422e+06       2.130085e+08
# 538           6.791490e+06        1.313711e+07       2.026457e+08
# 557           1.093918e+07        4.525125e+06       6.038811e+08
# 635           7.979963e+06        1.881688e+07       6.904690e+08
# 655           5.623230e+05        9.262751e+06       6.148150e+08
# ...                    ...                 ...                ...
# 148408        2.198622e+07        2.199710e+07       5.298427e+08
# 148994        4.347335e+06        1.344948e+07       6.703932e+07
# 148998        1.823716e+07        8.180771e+06       4.606069e+08
# 149014        3.634255e+06        1.354135e+07       6.029528e+08
# 150000        1.162685e+07        1.100175e+07       4.220447e+08
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 38           1.150316e+07      2.953252e+08      1.208252e+07
# 538          4.345867e+06      4.148526e+07      9.191686e+06
# 557          4.134867e+06      2.285394e+08      4.085765e+06
# 635          1.155723e+07      4.143671e+07      1.492056e+07
# 655          1.527788e+07      2.357034e+08      9.787240e+06
# ...                   ...               ...               ...
# 148408       4.755600e+06      1.771067e+07      1.610640e+07
# 148994       1.011186e+07      7.720227e+08      3.773220e+05
# 148998       1.119436e+07      3.305570e+08      2.329454e+06
# 149014       1.477651e+07      2.382396e+08      5.234383e+06
# 150000       8.288398e+06      4.211005e+08      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)
# 38            49727524.0       267689014.0
# 538           36072646.0       236941106.0
# 557           29908196.0       642815619.0
# 635           64954877.0       727897527.0
# 655           42450423.0       632356629.0
# ...                  ...               ...
# 148408        44841066.0       579178272.0
# 148994        45124501.0        90680481.0
# 148998        46062056.0       503379057.0
# 149014        37457488.0       626691030.0
# 150000               NaN               NaN
#
# [566 rows x 55 columns]

# %% [markdown]
# 565 rows with outliers

# %%
display(outlier.outlier_overview(df, 'TCP UL Retrans. Vol (Bytes)'))
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN              NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1       1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2       1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3       1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4       1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082022e+14   3.365069e+10  3.548311e+13
# 149997    97970.0  2.082019e+14   3.366345e+10  3.566051e+13
# 149998    98249.0  2.082017e+14   3.362189e+10  3.572121e+13
# 149999    97910.0  2.082021e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#            Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0       9.16456699548519E+015  ...        1.585461e+07        2.501332e+06
# 1                     L77566A  ...        2.024740e+07        1.911173e+07
# 2                     D42335A  ...        1.972566e+07        1.469958e+07
# 3                     T21824A  ...        2.138812e+07        1.514664e+07
# 4                     D88865A  ...        1.525938e+07        1.896287e+07
# ...                       ...  ...                 ...                 ...
# 149996                D20434A  ...        1.619167e+07        1.176343e+07
# 149997                D10223C  ...        1.387723e+07        8.288284e+06
# 149998                T51102A  ...        2.266051e+07        1.855903e+06
# 149999                L88342B  ...        8.817106e+06        8.305402e+06
# 150000                    NaN  ...        1.163407e+07        1.100941e+07
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0             8.198936e+06        9.656251e+06       2.780823e+08
# 1             1.833841e+07        1.722713e+07       6.087501e+08
# 2             1.758779e+07        6.163408e+06       2.295846e+08
# 3             1.399465e+07        1.097942e+06       7.995382e+08
# 4             1.712458e+07        4.152180e+05       5.277072e+08
# ...                    ...                 ...                ...
# 149996        1.788370e+07        1.967816e+07       5.266097e+08
# 149997        1.935015e+07        2.129315e+07       6.268931e+08
# 149998        9.963942e+06        5.065760e+06       5.535395e+08
# 149999        3.322253e+06        1.317259e+07       3.525370e+08
# 150000        1.162685e+07        1.100175e+07       4.220447e+08
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0            1.434415e+07      1.717444e+08      8.814393e+06
# 1            1.170709e+06      5.269042e+08      1.505514e+07
# 2            3.956300e+05      4.106926e+08      4.215763e+06
# 3            1.084972e+07      7.490399e+08      1.279728e+07
# 4            3.529801e+06      5.507095e+08      1.391032e+07
# ...                   ...               ...               ...
# 149996       9.197207e+06      3.264510e+06      1.348742e+07
# 149997       4.735033e+06      7.121804e+08      2.457758e+06
# 149998       1.339432e+07      1.211009e+08      1.131473e+07
# 149999       2.529475e+06      8.147131e+08      1.406930e+06
# 150000       8.288398e+06      4.211005e+08      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             36749741.0       308879636.0
# 1             53800391.0       653384965.0
# 2             27883638.0       279807335.0
# 3             43324218.0       846028530.0
# 4             38542814.0       569138589.0
# ...                  ...               ...
# 149996        57628851.0       574175259.0
# 149997        39135081.0       666648844.0
# 149998        34912224.0       592786405.0
# 149999        29626096.0       371895920.0
# 150000               NaN               NaN
#
# [96773 rows x 55 columns]

# %% [markdown]
# 125 rows with outliers

# %% [markdown]
# Calculate number of outliers for each numeric column

# %% [markdown]
# Select the numeric columns

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df.dtypes
# Out:
# Bearer Id                                   float64
# Start                                        object
# Start ms                                    float64
# End                                          object
# End ms                                      float64
# Dur. (ms)                                   float64
# IMSI                                        float64
# MSISDN/Number                               float64
# IMEI                                        float64
# Last Location Name                           object
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# 250 Kbps < DL TP < 1 Mbps (%)               float64
# DL TP > 1 Mbps (%)                          float64
# UL TP < 10 Kbps (%)                         float64
# 10 Kbps < UL TP < 50 Kbps (%)               float64
# 50 Kbps < UL TP < 300 Kbps (%)              float64
# UL TP > 300 Kbps (%)                        float64
# HTTP DL (Bytes)                             float64
# HTTP UL (Bytes)                             float64
# Activity Duration DL (ms)                   float64
# Activity Duration UL (ms)                   float64
# Dur. (ms).1                                 float64
# Handset Manufacturer                         object
# Handset Type                                 object
# Nb of sec with 125000B < Vol DL             float64
# Nb of sec with 1250B < Vol UL < 6250B       float64
# Nb of sec with 31250B < Vol DL < 125000B    float64
# Nb of sec with 37500B < Vol UL              float64
# Nb of sec with 6250B < Vol DL < 31250B      float64
# Nb of sec with 6250B < Vol UL < 37500B      float64
# Nb of sec with Vol DL < 6250B               float64
# Nb of sec with Vol UL < 1250B               float64
# Social Media DL (Bytes)                     float64
# Social Media UL (Bytes)                     float64
# Google DL (Bytes)                           float64
# Google UL (Bytes)                           float64
# Email DL (Bytes)                            float64
# Email UL (Bytes)                            float64
# Youtube DL (Bytes)                          float64
# Youtube UL (Bytes)                          float64
# Netflix DL (Bytes)                          float64
# Netflix UL (Bytes)                          float64
# Gaming DL (Bytes)                           float64
# Gaming UL (Bytes)                           float64
# Other DL (Bytes)                            float64
# Other UL (Bytes)                            float64
# Total UL (Bytes)                            float64
# Total DL (Bytes)                            float64
# dtype: object

# %%
num_cols = df.select_dtypes(include=np.number).columns

# %%
dlist = ['Bearer Id', 'Start ms', 'End ms', 'INSI', 'MSISDN/Number', 'IMEI']

# %%
num_cols = [el for el in num_cols if el not in dlist]

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of Dur. (ms) 2214
# Outliers from Z-scores method of IMSI 3
# Outliers from Z-scores method of Avg RTT DL (ms) 717
# Outliers from Z-scores method of Avg RTT UL (ms) 677
# Outliers from Z-scores method of Avg Bearer TP DL (kbps) 2983
# Outliers from Z-scores method of Avg Bearer TP UL (kbps) 4269
# Outliers from Z-scores method of TCP DL Retrans. Vol (Bytes) 416
# Outliers from Z-scores method of TCP UL Retrans. Vol (Bytes) 55
# Outliers from Z-scores method of DL TP < 50 Kbps (%) 3467
# Outliers from Z-scores method of 50 Kbps < DL TP < 250 Kbps (%) 3462
# Outliers from Z-scores method of 250 Kbps < DL TP < 1 Mbps (%) 3147
# Outliers from Z-scores method of DL TP > 1 Mbps (%) 3464
# Outliers from Z-scores method of UL TP < 10 Kbps (%) 2199
# Outliers from Z-scores method of 10 Kbps < UL TP < 50 Kbps (%) 2018
# Outliers from Z-scores method of 50 Kbps < UL TP < 300 Kbps (%) 1029
# Outliers from Z-scores method of UL TP > 300 Kbps (%) 749
# Outliers from Z-scores method of HTTP DL (Bytes) 314
# Outliers from Z-scores method of HTTP UL (Bytes) 394
# Outliers from Z-scores method of Activity Duration DL (ms) 3558
# Outliers from Z-scores method of Activity Duration UL (ms) 2958
# Outliers from Z-scores method of Dur. (ms).1 2214
# Outliers from Z-scores method of Nb of sec with 125000B < Vol DL 1122
# Outliers from Z-scores method of Nb of sec with 1250B < Vol UL < 6250B 616
# Outliers from Z-scores method of Nb of sec with 31250B < Vol DL < 125000B 1129
# Outliers from Z-scores method of Nb of sec with 37500B < Vol UL 130
# Outliers from Z-scores method of Nb of sec with 6250B < Vol DL < 31250B 1044
# Outliers from Z-scores method of Nb of sec with 6250B < Vol UL < 37500B 346
# Outliers from Z-scores method of Nb of sec with Vol DL < 6250B 2995
# Outliers from Z-scores method of Nb of sec with Vol UL < 1250B 3685
# Outliers from Z-scores method of Social Media DL (Bytes) 0
# Outliers from Z-scores method of Social Media UL (Bytes) 0
# Outliers from Z-scores method of Google DL (Bytes) 0
# Outliers from Z-scores method of Google UL (Bytes) 0
# Outliers from Z-scores method of Email DL (Bytes) 0
# Outliers from Z-scores method of Email UL (Bytes) 0
# Outliers from Z-scores method of Youtube DL (Bytes) 0
# Outliers from Z-scores method of Youtube UL (Bytes) 0
# Outliers from Z-scores method of Netflix DL (Bytes) 0
# Outliers from Z-scores method of Netflix UL (Bytes) 0
# Outliers from Z-scores method of Gaming DL (Bytes) 0
# Outliers from Z-scores method of Gaming UL (Bytes) 0
# Outliers from Z-scores method of Other DL (Bytes) 0
# Outliers from Z-scores method of Other UL (Bytes) 0
# Outliers from Z-scores method of Total UL (Bytes) 55
# Outliers from Z-scores method of Total DL (Bytes) 0

# %% [markdown]
# Handle outliers for each numeric column by scaling the data

# %%
df = outlier.handle_outliers(df, num_cols)
# Out:
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:34: RuntimeWarning: divide by zero encountered in log
#   df[col] = [np.log(x) for x in df[col]]

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of Dur. (ms) 500
# Outliers from Z-scores method of IMSI 3
# Outliers from Z-scores method of Avg RTT DL (ms) 0
# Outliers from Z-scores method of Avg RTT UL (ms) 0
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:51: RuntimeWarning: invalid value encountered in scalar subtract
#   z_score = (i-mean)/std
# Outliers from Z-scores method of Avg Bearer TP DL (kbps) 0
# Outliers from Z-scores method of Avg Bearer TP UL (kbps) 0
# Outliers from Z-scores method of TCP DL Retrans. Vol (Bytes) 29
# Outliers from Z-scores method of TCP UL Retrans. Vol (Bytes) 311
# Outliers from Z-scores method of DL TP < 50 Kbps (%) 0
# Outliers from Z-scores method of 50 Kbps < DL TP < 250 Kbps (%) 0
# Outliers from Z-scores method of 250 Kbps < DL TP < 1 Mbps (%) 0
# Outliers from Z-scores method of DL TP > 1 Mbps (%) 0
# Outliers from Z-scores method of UL TP < 10 Kbps (%) 0
# Outliers from Z-scores method of 10 Kbps < UL TP < 50 Kbps (%) 0
# Outliers from Z-scores method of 50 Kbps < UL TP < 300 Kbps (%) 0
# Outliers from Z-scores method of UL TP > 300 Kbps (%) 0
# Outliers from Z-scores method of HTTP DL (Bytes) 0
# Outliers from Z-scores method of HTTP UL (Bytes) 4
# Outliers from Z-scores method of Activity Duration DL (ms) 0
# Outliers from Z-scores method of Activity Duration UL (ms) 0
# Outliers from Z-scores method of Dur. (ms).1 500
# Outliers from Z-scores method of Nb of sec with 125000B < Vol DL 0
# Outliers from Z-scores method of Nb of sec with 1250B < Vol UL < 6250B 24
# Outliers from Z-scores method of Nb of sec with 31250B < Vol DL < 125000B 0
# Outliers from Z-scores method of Nb of sec with 37500B < Vol UL 167
# Outliers from Z-scores method of Nb of sec with 6250B < Vol DL < 31250B 0
# Outliers from Z-scores method of Nb of sec with 6250B < Vol UL < 37500B 393
# Outliers from Z-scores method of Nb of sec with Vol DL < 6250B 3
# Outliers from Z-scores method of Nb of sec with Vol UL < 1250B 6
# Outliers from Z-scores method of Social Media DL (Bytes) 2752
# Outliers from Z-scores method of Social Media UL (Bytes) 0
# Outliers from Z-scores method of Google DL (Bytes) 2811
# Outliers from Z-scores method of Google UL (Bytes) 2766
# Outliers from Z-scores method of Email DL (Bytes) 2740
# Outliers from Z-scores method of Email UL (Bytes) 2728
# Outliers from Z-scores method of Youtube DL (Bytes) 2750
# Outliers from Z-scores method of Youtube UL (Bytes) 2808
# Outliers from Z-scores method of Netflix DL (Bytes) 2767
# Outliers from Z-scores method of Netflix UL (Bytes) 2755
# Outliers from Z-scores method of Gaming DL (Bytes) 2759
# Outliers from Z-scores method of Gaming UL (Bytes) 2782
# Outliers from Z-scores method of Other DL (Bytes) 2825
# Outliers from Z-scores method of Other UL (Bytes) 2799
# Outliers from Z-scores method of Total UL (Bytes) 1471
# Outliers from Z-scores method of Total DL (Bytes) 1251

# %% [markdown]
# Data needs further preprocessing as there are some outliers in the data

# %%
outlier_columns = []
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    if len(sample_outliers) > 0:
        outlier_columns.append(col)

# %%
len(outlier_columns)
# Out:
# 26

# %%
df_cop = df.copy()

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

# generate 1000 data points randomly drawn from an exponential distribution
scaled_data = df.copy()

scaled_data.sample(5)
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 74817   7.349883e+18   4/26/2019 9:08     666.0   4/27/2019 3:55   227.0
# 49477   7.277826e+18   4/25/2019 7:51     895.0   4/26/2019 7:47   616.0
# 15821   1.304243e+19  4/24/2019 19:01     423.0   4/25/2019 0:35   845.0
# 16660   6.917538e+18  4/24/2019 19:15     598.0  4/24/2019 23:44    47.0
# 112737  1.311448e+19  4/27/2019 22:26     451.0   4/29/2019 7:33   631.0
#
#         Dur. (ms)       IMSI  MSISDN/Number          IMEI Last Location Name  \
# 74817   11.121482  32.969527   3.369869e+10  3.567741e+13            D14680C
# 49477   11.364298  32.969528   3.364503e+10  3.590391e+13            D10154C
# 15821    9.904937  32.969527   3.366931e+10  3.572141e+13            T79738B
# 16660    9.688932  32.969524   3.376936e+10  3.598781e+13            G01068C
# 112737  11.688684  32.969527   3.366445e+10  3.592551e+13            L72457B
#
#         ...  Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# 74817   ...           16.660803           11.087084           16.703033
# 49477   ...           15.950418           14.045545           16.046802
# 15821   ...           15.401171           15.854420           16.336935
# 16660   ...           16.424613           16.361592           15.195536
# 112737  ...           15.729618           16.515073           15.855842
#
#         Netflix UL (Bytes)  Gaming DL (Bytes)  Gaming UL (Bytes)  \
# 74817            16.367363          20.269693          15.998268
# 49477            15.786846          20.270922          15.666869
# 15821            14.849481          19.672500          16.081595
# 16660            16.711137          20.416649          16.545345
# 112737           16.773623          19.126756          12.148491
#
#         Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)
# 74817          19.070124         16.455146         17.481494         20.339426
# 49477          19.062208         16.619789         17.363150         20.318983
# 15821          20.402075         15.952868         17.241399         19.737333
# 16660          20.213389         16.215135         17.885444         20.456942
# 112737         20.179040         15.047037         17.499235         19.246995
#
# [5 rows x 55 columns]

# %%
df_cop[outlier_columns].shape #= scaled_data
scaled_data.shape
# Out:
# (150001, 55)

# %%
scaled_data = minmax_scaler.fit_transform(scaled_data[outlier_columns])

# %%
scaled_data.shape
# Out:
# (150001, 26)

# %%
outlier_columns = []
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df_cop[col])
    if len(sample_outliers) > 0:
        outlier_columns.append(col)
# Out:
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:51: RuntimeWarning: invalid value encountered in scalar subtract
#   z_score = (i-mean)/std

# %%
len(outlier_columns)
# Out:
# 26

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df_cop[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of Dur. (ms) 500
# Outliers from Z-scores method of IMSI 3
# Outliers from Z-scores method of Avg RTT DL (ms) 0
# Outliers from Z-scores method of Avg RTT UL (ms) 0
# Outliers from Z-scores method of Avg Bearer TP DL (kbps) 0
# Outliers from Z-scores method of Avg Bearer TP UL (kbps) 0
# Outliers from Z-scores method of TCP DL Retrans. Vol (Bytes) 29
# Outliers from Z-scores method of TCP UL Retrans. Vol (Bytes) 311
# Outliers from Z-scores method of DL TP < 50 Kbps (%) 0
# Outliers from Z-scores method of 50 Kbps < DL TP < 250 Kbps (%) 0
# Outliers from Z-scores method of 250 Kbps < DL TP < 1 Mbps (%) 0
# Outliers from Z-scores method of DL TP > 1 Mbps (%) 0
# Outliers from Z-scores method of UL TP < 10 Kbps (%) 0
# Outliers from Z-scores method of 10 Kbps < UL TP < 50 Kbps (%) 0
# Outliers from Z-scores method of 50 Kbps < UL TP < 300 Kbps (%) 0
# Outliers from Z-scores method of UL TP > 300 Kbps (%) 0
# Outliers from Z-scores method of HTTP DL (Bytes) 0
# Outliers from Z-scores method of HTTP UL (Bytes) 4
# Outliers from Z-scores method of Activity Duration DL (ms) 0
# Outliers from Z-scores method of Activity Duration UL (ms) 0
# Outliers from Z-scores method of Dur. (ms).1 500
# Outliers from Z-scores method of Nb of sec with 125000B < Vol DL 0
# Outliers from Z-scores method of Nb of sec with 1250B < Vol UL < 6250B 24
# Outliers from Z-scores method of Nb of sec with 31250B < Vol DL < 125000B 0
# Outliers from Z-scores method of Nb of sec with 37500B < Vol UL 167
# Outliers from Z-scores method of Nb of sec with 6250B < Vol DL < 31250B 0
# Outliers from Z-scores method of Nb of sec with 6250B < Vol UL < 37500B 393
# Outliers from Z-scores method of Nb of sec with Vol DL < 6250B 3
# Outliers from Z-scores method of Nb of sec with Vol UL < 1250B 6
# Outliers from Z-scores method of Social Media DL (Bytes) 2752
# Outliers from Z-scores method of Social Media UL (Bytes) 0
# Outliers from Z-scores method of Google DL (Bytes) 2811
# Outliers from Z-scores method of Google UL (Bytes) 2766
# Outliers from Z-scores method of Email DL (Bytes) 2740
# Outliers from Z-scores method of Email UL (Bytes) 2728
# Outliers from Z-scores method of Youtube DL (Bytes) 2750
# Outliers from Z-scores method of Youtube UL (Bytes) 2808
# Outliers from Z-scores method of Netflix DL (Bytes) 2767
# Outliers from Z-scores method of Netflix UL (Bytes) 2755
# Outliers from Z-scores method of Gaming DL (Bytes) 2759
# Outliers from Z-scores method of Gaming UL (Bytes) 2782
# Outliers from Z-scores method of Other DL (Bytes) 2825
# Outliers from Z-scores method of Other UL (Bytes) 2799
# Outliers from Z-scores method of Total UL (Bytes) 1471
# Outliers from Z-scores method of Total DL (Bytes) 1251

# %%
df_cop[num_cols].boxplot()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# <Axes: >

# %% [markdown]
# Most of the outliers have been handled

# %%
pl.plot_box(df_cop, 'Dur. (ms)', 'Total Duration of the xDR (in ms) after outlier handling')

# %%
df_cop.describe()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           Bearer Id       Start ms         End ms      Dur. (ms)  \
# count  1.490100e+05  150000.000000  150000.000000  150000.000000
# mean   1.013887e+19     499.188200     498.800880      11.315589
# std    2.893173e+18     288.611834     288.097653       0.728960
# min    6.917538e+18       0.000000       0.000000       8.873748
# 25%    7.349883e+18     250.000000     251.000000      10.958505
# 50%    7.349883e+18     499.000000     500.000000      11.366731
# 75%    1.304243e+19     749.000000     750.000000      11.793811
# max    1.318654e+19     999.000000     999.000000      14.435730
#
#                 IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# count  149431.000000   1.489350e+05  1.494290e+05     1.221720e+05
# mean       32.969528   4.188282e+10  4.847455e+13             -inf
# std         0.000103   2.447443e+12  2.241637e+13              NaN
# min        32.949372   3.360100e+10  4.400152e+11             -inf
# 25%        32.969527   3.365130e+10  3.546071e+13     3.465736e+00
# 50%        32.969528   3.366371e+10  3.572201e+13     3.806662e+00
# 75%        32.969529   3.368349e+10  8.611970e+13     4.248495e+00
# max        32.997344   8.823971e+14  9.900120e+13     1.148167e+01
#
#        Avg RTT UL (ms)  Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  \
# count     1.221890e+05             1.500000e+05  ...       150001.000000
# mean              -inf                     -inf  ...           15.963339
# std                NaN                      NaN  ...            0.999826
# min               -inf                     -inf  ...            3.970292
# 25%       6.931472e-01             3.761200e+00  ...           15.579128
# 50%       1.609438e+00             4.143135e+00  ...           16.267896
# 75%       2.708050e+00             9.888919e+00  ...           16.674765
# max       8.870663e+00             1.284307e+01  ...           16.962207
#
#        Youtube UL (Bytes)  Netflix DL (Bytes)  Netflix UL (Bytes)  \
# count       150001.000000       150001.000000       150001.000000
# mean            15.907689           15.960316           15.905965
# std              1.001628            1.002698            1.001366
# min              4.653960            3.737670            3.555348
# 25%             15.523520           15.569422           15.515882
# 50%             16.214628           16.270148           16.213077
# 75%             16.619814           16.676023           16.619311
# max             16.907097           16.962211           16.907096
#
#        Gaming DL (Bytes)  Gaming UL (Bytes)  Other DL (Bytes)  \
# count      150001.000000      150001.000000     150001.000000
# mean           19.552311          15.623673         19.550172
# std             1.001953           1.000328          1.004539
# min             7.830426           4.077537          8.098643
# 25%            19.164869          15.233419         19.163508
# 50%            19.863847          15.930706         19.860049
# 75%            20.266256          16.335754         20.263912
# max            20.553002          16.622428         20.553002
#
#        Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)
# count     150001.000000     150000.000000     150000.000000
# mean          15.619125         17.489536         19.716028
# std            1.006696          0.304413          0.760147
# min            4.997212         14.868739         15.777581
# 25%           15.237641         17.318723         19.309011
# 50%           15.927791         17.532572         19.937655
# 75%           16.331928         17.708029         20.316358
# max           16.622429         18.176458         20.621199
#
# [8 rows x 50 columns]

# %% [markdown]
# Save the data

# %%
df_cop.to_csv('../data/cleaned_data_outliers.csv', index=False)
