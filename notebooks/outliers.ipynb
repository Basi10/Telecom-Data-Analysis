# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0,rpath)
from src.preprocessing import PreProcess
from src.overview import Overview
from src.outlier import Outlier
from src.plots import Plot

# %%
df = pd.read_csv('../data/cleaned_data2.csv')

# %%
#df2 = pd.read_excel("../data/Week1_challenge_data_source.xlsx")

# %%
outlier = Outlier(df)

# %%
df.head()
# Out:
#       bearer_id            start  start_ms              end  end_ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    dur._(ms)          imsi  msisdn/number          imei  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       last_location_name  ...  youtube_dl_(bytes)  youtube_ul_(bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    netflix_dl_(bytes)  netflix_ul_(bytes)  gaming_dl_(bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    gaming_ul_(bytes)  other_dl_(bytes)  other_ul_(bytes)  total_ul_(bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    total_dl_(bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
df.columns
# Out:
# Index(['bearer_id', 'start', 'start_ms', 'end', 'end_ms', 'dur._(ms)', 'imsi',
#        'msisdn/number', 'imei', 'last_location_name', 'avg_rtt_dl_(ms)',
#        'avg_rtt_ul_(ms)', 'avg_bearer_tp_dl_(kbps)', 'avg_bearer_tp_ul_(kbps)',
#        'tcp_dl_retrans._vol_(bytes)', 'tcp_ul_retrans._vol_(bytes)',
#        'dl_tp_<_50_kbps_(%)', '50_kbps_<_dl_tp_<_250_kbps_(%)',
#        '250_kbps_<_dl_tp_<_1_mbps_(%)', 'dl_tp_>_1_mbps_(%)',
#        'ul_tp_<_10_kbps_(%)', '10_kbps_<_ul_tp_<_50_kbps_(%)',
#        '50_kbps_<_ul_tp_<_300_kbps_(%)', 'ul_tp_>_300_kbps_(%)',
#        'http_dl_(bytes)', 'http_ul_(bytes)', 'activity_duration_dl_(ms)',
#        'activity_duration_ul_(ms)', 'dur._(ms).1', 'handset_manufacturer',
#        'handset_type', 'nb_of_sec_with_125000b_<_vol_dl',
#        'nb_of_sec_with_1250b_<_vol_ul_<_6250b',
#        'nb_of_sec_with_31250b_<_vol_dl_<_125000b',
#        'nb_of_sec_with_37500b_<_vol_ul',
#        'nb_of_sec_with_6250b_<_vol_dl_<_31250b',
#        'nb_of_sec_with_6250b_<_vol_ul_<_37500b',
#        'nb_of_sec_with_vol_dl_<_6250b', 'nb_of_sec_with_vol_ul_<_1250b',
#        'social_media_dl_(bytes)', 'social_media_ul_(bytes)',
#        'google_dl_(bytes)', 'google_ul_(bytes)', 'email_dl_(bytes)',
#        'email_ul_(bytes)', 'youtube_dl_(bytes)', 'youtube_ul_(bytes)',
#        'netflix_dl_(bytes)', 'netflix_ul_(bytes)', 'gaming_dl_(bytes)',
#        'gaming_ul_(bytes)', 'other_dl_(bytes)', 'other_ul_(bytes)',
#        'total_ul_(bytes)', 'total_dl_(bytes)'],
#       dtype='object')

# %% [markdown]
# Initialize plot class

# %%
pl = Plot()

# %%
# dfdfsdsdsdklkjjkjkjjkklkkjjikjjkjkjkjjkkjjfkldklkldfkldfdfdfdffddffpl.plot_box(df, 'nb_of_sec_with_vol_ul_<_1250b', 'Number of seconds with IP Volume DL < 1250B')

# %%
pl.plot_box(df, 'dur._(ms)', 'Total Duration of the xDR (in ms)')

# %%
pl.plot_box(df, 'avg_rtt_dl_(ms)', 'Average Round Trip Time measurement Downlink direction (msecond)')

# %%
pl.plot_box(df, 'tcp_ul_retrans._vol_(bytes)', 'TCP volume of Uplink packets detected as retransmitted (bytes)')

# %%
#pl.plot_box(df, 'Activity Duration UL (ms)', 'Activity duration ul(ms)')

# %%
#pl.plot_box(df, 'Youtube UL (Bytes)', 'YouTube data volume (in Bytes) sent by the MS during this session')

# %%
#pl.plot_box(df, 'Total UL (Bytes)', 'Total DL (Bytes)Data volume (in Bytes) received by the MS during this session (IP layer + overhead)')

# %%
#pl.plot_box(df, 'Total DL (Bytes)', 'Total UL (Bytes)Data volume (in Bytes) sent by the MS during this session (IP layer + overhead)')

# %% [markdown]
# It can be seen that most of the column have outliers

# %% [markdown]
# Get Outlier overview

# %%
display(outlier.outlier_overview(df, 'activity_duration_ul_(ms)'))
# Out:
#            bearer_id            start  start_ms              end  end_ms  \
# 38      7.277826e+18  4/18/2019 15:40     982.0  4/25/2019 15:40    33.0
# 538     7.277826e+18  4/23/2019 23:45     419.0  4/24/2019 23:45   313.0
# 557     1.304243e+19  4/23/2019 23:56     766.0  4/24/2019 23:56   385.0
# 635     1.304243e+19   4/24/2019 0:09     773.0   4/25/2019 0:09   678.0
# 655     7.277826e+18   4/24/2019 0:11     540.0   4/25/2019 0:11   513.0
# ...              ...              ...       ...              ...     ...
# 148359  1.304243e+19   4/29/2019 7:08     248.0   4/30/2019 7:08   208.0
# 148408  1.304243e+19   4/29/2019 7:09     731.0   4/30/2019 7:09   745.0
# 148994  1.304243e+19   4/29/2019 7:16     675.0   4/30/2019 7:16   689.0
# 148998  7.277826e+18   4/29/2019 7:16     452.0   4/30/2019 7:16   469.0
# 149014  1.304243e+19   4/29/2019 7:17     752.0   4/30/2019 7:17   596.0
#
#         dur._(ms)          imsi  msisdn/number          imei  \
# 38       604800.0  2.082095e+14   3.376394e+10  8.616400e+13
# 538       86399.0  2.082017e+14   3.366726e+10  8.637690e+13
# 557       86400.0  2.082017e+14   3.366344e+10  8.637690e+13
# 635       86399.0  2.082015e+14   3.366045e+10  8.637690e+13
# 655       86399.0  2.082017e+14   3.365830e+10  3.520271e+13
# ...           ...           ...            ...           ...
# 148359    86399.0  2.082014e+14   3.366916e+10  8.637690e+13
# 148408    86400.0  2.082017e+14   3.366057e+10  8.637690e+13
# 148994    86400.0  2.082018e+14   3.366725e+10  8.637690e+13
# 148998    86400.0  2.082017e+14   3.376216e+10  8.637690e+13
# 149014    86399.0  2.082018e+14   3.369922e+10  8.637690e+13
#
#        last_location_name  ...  youtube_dl_(bytes)  youtube_ul_(bytes)  \
# 38                T86868A  ...          21679309.0          16508079.0
# 538               D84798A  ...          15444612.0           6669529.0
# 557               D83916A  ...          16220887.0          15928572.0
# 635               D92712B  ...          20529706.0          15820629.0
# 655               K14666C  ...           2504633.0           3938252.0
# ...                   ...  ...                 ...                 ...
# 148359            T85713B  ...           4679867.0          20549288.0
# 148408            T85784A  ...          12264941.0           1357151.0
# 148994            D85941B  ...          16205072.0          20135265.0
# 148998            T78199C  ...          16189977.0          19719459.0
# 149014            D93141C  ...          11016096.0           2003353.0
#
#         netflix_dl_(bytes)  netflix_ul_(bytes)  gaming_dl_(bytes)  \
# 38              23243098.0           6438422.0        213008522.0
# 538              6791490.0          13137110.0        202645712.0
# 557             10939175.0           4525125.0        603881110.0
# 635              7979963.0          18816877.0        690468982.0
# 655               562323.0           9262751.0        614815032.0
# ...                    ...                 ...                ...
# 148359           7150333.0          19695300.0        397284051.0
# 148408          21986225.0          21997101.0        529842696.0
# 148994           4347335.0          13449484.0         67039315.0
# 148998          18237162.0           8180771.0        460606860.0
# 149014           3634255.0          13541351.0        602952846.0
#
#         gaming_ul_(bytes)  other_dl_(bytes)  other_ul_(bytes)  \
# 38             11503163.0       295325210.0        12082520.0
# 538             4345867.0        41485262.0         9191686.0
# 557             4134867.0       228539389.0         4085765.0
# 635            11557228.0        41436710.0        14920555.0
# 655            15277882.0       235703378.0         9787240.0
# ...                   ...               ...               ...
# 148359          4579066.0       329851993.0        11505030.0
# 148408          4755600.0        17710673.0        16106399.0
# 148994         10111864.0       772022712.0          377322.0
# 148998         11194362.0       330556976.0         2329454.0
# 149014         14776509.0       238239601.0         5234383.0
#
#         total_ul_(bytes)  total_dl_(bytes)
# 38            49727524.0       267689014.0
# 538           36072646.0       236941106.0
# 557           29908196.0       642815619.0
# 635           64954877.0       727897527.0
# 655           42450423.0       632356629.0
# ...                  ...               ...
# 148359        59572655.0       419875450.0
# 148408        44841066.0       579178272.0
# 148994        45124501.0        90680481.0
# 148998        46062056.0       503379057.0
# 149014        37457488.0       626691030.0
#
# [565 rows x 55 columns]

# %% [markdown]
# 565 rows with outliers

# %%
display(outlier.outlier_overview(df, 'tcp_ul_retrans._vol_(bytes)'))
# Out:
#            bearer_id           start  start_ms             end  end_ms  \
# 566     1.304243e+19  4/24/2019 0:00     698.0  4/25/2019 0:00   236.0
# 788     1.304243e+19  4/24/2019 0:22     489.0  4/25/2019 0:22   461.0
# 821     1.304243e+19  4/24/2019 0:26     254.0  4/25/2019 0:26   177.0
# 1246    1.304243e+19  4/24/2019 1:15     318.0  4/25/2019 1:15   734.0
# 1381    7.277826e+18  4/24/2019 1:26     132.0  4/25/2019 1:26    44.0
# ...              ...             ...       ...             ...     ...
# 143416  7.277826e+18  4/29/2019 4:55      60.0  4/30/2019 4:55   674.0
# 143597  1.304243e+19  4/29/2019 4:59     318.0  4/30/2019 4:59   193.0
# 143662  7.277826e+18  4/29/2019 5:01     107.0  4/30/2019 5:01   948.0
# 145428  1.304243e+19  4/29/2019 6:09     700.0  4/30/2019 6:09   140.0
# 147305  1.304243e+19  4/29/2019 6:53     834.0  4/30/2019 6:53   872.0
#
#         dur._(ms)          imsi  msisdn/number          imei  \
# 566       86403.0  2.082015e+14   3.365829e+10  3.592631e+13
# 788       86399.0  2.082014e+14   3.366027e+10  8.654080e+13
# 821       86399.0  2.082010e+14   3.366228e+10  8.654080e+13
# 1246      86452.0  2.082017e+14   3.376314e+10  8.637690e+13
# 1381      86399.0  2.082018e+14   3.366845e+10  8.637690e+13
# ...           ...           ...            ...           ...
# 143416    86400.0  2.082019e+14   3.365802e+10  8.672620e+13
# 143597    86399.0  2.082017e+14   3.365927e+10  8.637690e+13
# 143662    86398.0  2.082010e+14   3.369938e+10  8.637690e+13
# 145428    86400.0  2.082017e+14   3.366833e+10  8.637690e+13
# 147305    86400.0  2.082017e+14   3.365857e+10  8.637690e+13
#
#        last_location_name  ...  youtube_dl_(bytes)  youtube_ul_(bytes)  \
# 566               L42997A  ...          14167452.0          16687696.0
# 788               T88349B  ...            787496.0          15618631.0
# 821               L85966B  ...          14040294.0           2757831.0
# 1246              T88449B  ...           4952237.0           8113457.0
# 1381              T21355A  ...          17235232.0          12879086.0
# ...                   ...  ...                 ...                 ...
# 143416            L10326C  ...          19658514.0           9696167.0
# 143597            T88844C  ...           3404332.0           9622909.0
# 143662            D93656A  ...           1824702.0          20827969.0
# 145428            D88357A  ...          20392237.0           9395084.0
# 147305            D93909B  ...           2056331.0          20183370.0
#
#         netflix_dl_(bytes)  netflix_ul_(bytes)  gaming_dl_(bytes)  \
# 566             20674616.0          15219817.0        667514871.0
# 788             12824807.0          10070595.0        832811516.0
# 821             17429785.0          15843551.0         41103853.0
# 1246            22300544.0           3575703.0        231968638.0
# 1381            17019426.0           5646999.0        267351464.0
# ...                    ...                 ...                ...
# 143416          10445046.0          10645489.0         69768358.0
# 143597          10899189.0           4644588.0        314857668.0
# 143662            220153.0           8444865.0        824128190.0
# 145428           4335545.0          15007554.0         24591692.0
# 147305          11364644.0          19575271.0        194644882.0
#
#         gaming_ul_(bytes)  other_dl_(bytes)  other_ul_(bytes)  \
# 566            13291774.0       342138442.0        13294433.0
# 788             3650083.0       405294647.0         6010671.0
# 821             2635642.0       672644941.0          609546.0
# 1246            6783826.0       672789523.0        12621381.0
# 1381           14525412.0       740161901.0         9615407.0
# ...                   ...               ...               ...
# 143416          9369007.0       422158065.0         5331060.0
# 143597          1998381.0       183518923.0        13099413.0
# 143662          4161163.0       221240777.0        12139630.0
# 145428         14249920.0       136229675.0         7042829.0
# 147305          6271005.0       138016212.0        10571212.0
#
#         total_ul_(bytes)  total_dl_(bytes)
# 566           62025879.0       712700408.0
# 788           37234541.0       858057935.0
# 821           26706635.0        81434881.0
# 1246          35045982.0       267636706.0
# 1381          43983168.0       310983536.0
# ...                  ...               ...
# 143416        39155404.0       109745693.0
# 143597        32361826.0       344894438.0
# 143662        47152790.0       834468459.0
# 145428        46273702.0        59930864.0
# 147305        60417571.0       213087467.0
#
# [125 rows x 55 columns]

# %% [markdown]
# 125 rows with outliers

# %% [markdown]
# Calculate number of outliers for each numeric column

# %% [markdown]
# Select the numeric columns

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df.dtypes
# Out:
# bearer_id                                   float64
# start                                        object
# start_ms                                    float64
# end                                          object
# end_ms                                      float64
# dur._(ms)                                   float64
# imsi                                        float64
# msisdn/number                               float64
# imei                                        float64
# last_location_name                           object
# avg_rtt_dl_(ms)                             float64
# avg_rtt_ul_(ms)                             float64
# avg_bearer_tp_dl_(kbps)                     float64
# avg_bearer_tp_ul_(kbps)                     float64
# tcp_dl_retrans._vol_(bytes)                 float64
# tcp_ul_retrans._vol_(bytes)                 float64
# dl_tp_<_50_kbps_(%)                         float64
# 50_kbps_<_dl_tp_<_250_kbps_(%)              float64
# 250_kbps_<_dl_tp_<_1_mbps_(%)               float64
# dl_tp_>_1_mbps_(%)                          float64
# ul_tp_<_10_kbps_(%)                         float64
# 10_kbps_<_ul_tp_<_50_kbps_(%)               float64
# 50_kbps_<_ul_tp_<_300_kbps_(%)              float64
# ul_tp_>_300_kbps_(%)                        float64
# http_dl_(bytes)                             float64
# http_ul_(bytes)                             float64
# activity_duration_dl_(ms)                   float64
# activity_duration_ul_(ms)                   float64
# dur._(ms).1                                 float64
# handset_manufacturer                         object
# handset_type                                 object
# nb_of_sec_with_125000b_<_vol_dl             float64
# nb_of_sec_with_1250b_<_vol_ul_<_6250b       float64
# nb_of_sec_with_31250b_<_vol_dl_<_125000b    float64
# nb_of_sec_with_37500b_<_vol_ul              float64
# nb_of_sec_with_6250b_<_vol_dl_<_31250b      float64
# nb_of_sec_with_6250b_<_vol_ul_<_37500b      float64
# nb_of_sec_with_vol_dl_<_6250b               float64
# nb_of_sec_with_vol_ul_<_1250b               float64
# social_media_dl_(bytes)                     float64
# social_media_ul_(bytes)                     float64
# google_dl_(bytes)                           float64
# google_ul_(bytes)                           float64
# email_dl_(bytes)                            float64
# email_ul_(bytes)                            float64
# youtube_dl_(bytes)                          float64
# youtube_ul_(bytes)                          float64
# netflix_dl_(bytes)                          float64
# netflix_ul_(bytes)                          float64
# gaming_dl_(bytes)                           float64
# gaming_ul_(bytes)                           float64
# other_dl_(bytes)                            float64
# other_ul_(bytes)                            float64
# total_ul_(bytes)                            float64
# total_dl_(bytes)                            float64
# dtype: object

# %%
num_cols = df.select_dtypes(include=np.number).columns

# %%
dlist = ['bearer_id', 'start_ms', 'end_ms', 'imsi', 'msisdn/number', 'imei']

# %%
num_cols = [el for el in num_cols if el not in dlist]

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of dur._(ms) 2214
# Outliers from Z-scores method of avg_rtt_dl_(ms) 818
# Outliers from Z-scores method of avg_rtt_ul_(ms) 751
# Outliers from Z-scores method of avg_bearer_tp_dl_(kbps) 2983
# Outliers from Z-scores method of avg_bearer_tp_ul_(kbps) 4269
# Outliers from Z-scores method of tcp_dl_retrans._vol_(bytes) 550
# Outliers from Z-scores method of tcp_ul_retrans._vol_(bytes) 97
# Outliers from Z-scores method of dl_tp_<_50_kbps_(%) 3467
# Outliers from Z-scores method of 50_kbps_<_dl_tp_<_250_kbps_(%) 3462
# Outliers from Z-scores method of 250_kbps_<_dl_tp_<_1_mbps_(%) 3147
# Outliers from Z-scores method of dl_tp_>_1_mbps_(%) 3464
# Outliers from Z-scores method of ul_tp_<_10_kbps_(%) 2199
# Outliers from Z-scores method of 10_kbps_<_ul_tp_<_50_kbps_(%) 2018
# Outliers from Z-scores method of 50_kbps_<_ul_tp_<_300_kbps_(%) 1029
# Outliers from Z-scores method of ul_tp_>_300_kbps_(%) 749
# Outliers from Z-scores method of http_dl_(bytes) 552
# Outliers from Z-scores method of http_ul_(bytes) 691
# Outliers from Z-scores method of activity_duration_dl_(ms) 3558
# Outliers from Z-scores method of activity_duration_ul_(ms) 2958
# Outliers from Z-scores method of dur._(ms).1 2214
# Outliers from Z-scores method of nb_of_sec_with_125000b_<_vol_dl 2602
# Outliers from Z-scores method of nb_of_sec_with_1250b_<_vol_ul_<_6250b 1211
# Outliers from Z-scores method of nb_of_sec_with_31250b_<_vol_dl_<_125000b 2655
# Outliers from Z-scores method of nb_of_sec_with_37500b_<_vol_ul 371
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_dl_<_31250b 2582
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_ul_<_37500b 707
# Outliers from Z-scores method of nb_of_sec_with_vol_dl_<_6250b 3010
# Outliers from Z-scores method of nb_of_sec_with_vol_ul_<_1250b 3708
# Outliers from Z-scores method of social_media_dl_(bytes) 0
# Outliers from Z-scores method of social_media_ul_(bytes) 0
# Outliers from Z-scores method of google_dl_(bytes) 0
# Outliers from Z-scores method of google_ul_(bytes) 0
# Outliers from Z-scores method of email_dl_(bytes) 0
# Outliers from Z-scores method of email_ul_(bytes) 0
# Outliers from Z-scores method of youtube_dl_(bytes) 0
# Outliers from Z-scores method of youtube_ul_(bytes) 0
# Outliers from Z-scores method of netflix_dl_(bytes) 0
# Outliers from Z-scores method of netflix_ul_(bytes) 0
# Outliers from Z-scores method of gaming_dl_(bytes) 0
# Outliers from Z-scores method of gaming_ul_(bytes) 0
# Outliers from Z-scores method of other_dl_(bytes) 0
# Outliers from Z-scores method of other_ul_(bytes) 0
# Outliers from Z-scores method of total_ul_(bytes) 55
# Outliers from Z-scores method of total_dl_(bytes) 0

# %% [markdown]
# Handle outliers for each numeric column by scaling the data

# %%
df = outlier.handle_outliers(df, num_cols)
# Out:
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:34: RuntimeWarning: divide by zero encountered in log
#   df[col] = [np.log(x) for x in df[col]]

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of dur._(ms) 500
# Outliers from Z-scores method of avg_rtt_dl_(ms) 0
# Outliers from Z-scores method of avg_rtt_ul_(ms) 0
# Outliers from Z-scores method of avg_bearer_tp_dl_(kbps) 0
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:51: RuntimeWarning: invalid value encountered in scalar subtract
#   z_score = (i-mean)/std
# Outliers from Z-scores method of avg_bearer_tp_ul_(kbps) 0
# Outliers from Z-scores method of tcp_dl_retrans._vol_(bytes) 3049
# Outliers from Z-scores method of tcp_ul_retrans._vol_(bytes) 3857
# Outliers from Z-scores method of dl_tp_<_50_kbps_(%) 0
# Outliers from Z-scores method of 50_kbps_<_dl_tp_<_250_kbps_(%) 0
# Outliers from Z-scores method of 250_kbps_<_dl_tp_<_1_mbps_(%) 0
# Outliers from Z-scores method of dl_tp_>_1_mbps_(%) 0
# Outliers from Z-scores method of ul_tp_<_10_kbps_(%) 0
# Outliers from Z-scores method of 10_kbps_<_ul_tp_<_50_kbps_(%) 0
# Outliers from Z-scores method of 50_kbps_<_ul_tp_<_300_kbps_(%) 0
# Outliers from Z-scores method of ul_tp_>_300_kbps_(%) 0
# Outliers from Z-scores method of http_dl_(bytes) 2530
# Outliers from Z-scores method of http_ul_(bytes) 2171
# Outliers from Z-scores method of activity_duration_dl_(ms) 0
# Outliers from Z-scores method of activity_duration_ul_(ms) 0
# Outliers from Z-scores method of dur._(ms).1 500
# Outliers from Z-scores method of nb_of_sec_with_125000b_<_vol_dl 3115
# Outliers from Z-scores method of nb_of_sec_with_1250b_<_vol_ul_<_6250b 5119
# Outliers from Z-scores method of nb_of_sec_with_31250b_<_vol_dl_<_125000b 4372
# Outliers from Z-scores method of nb_of_sec_with_37500b_<_vol_ul 6618
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_dl_<_31250b 4048
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_ul_<_37500b 3354
# Outliers from Z-scores method of nb_of_sec_with_vol_dl_<_6250b 3
# Outliers from Z-scores method of nb_of_sec_with_vol_ul_<_1250b 6
# Outliers from Z-scores method of social_media_dl_(bytes) 2752
# Outliers from Z-scores method of social_media_ul_(bytes) 0
# Outliers from Z-scores method of google_dl_(bytes) 2811
# Outliers from Z-scores method of google_ul_(bytes) 2766
# Outliers from Z-scores method of email_dl_(bytes) 2740
# Outliers from Z-scores method of email_ul_(bytes) 2728
# Outliers from Z-scores method of youtube_dl_(bytes) 2750
# Outliers from Z-scores method of youtube_ul_(bytes) 2808
# Outliers from Z-scores method of netflix_dl_(bytes) 2767
# Outliers from Z-scores method of netflix_ul_(bytes) 2755
# Outliers from Z-scores method of gaming_dl_(bytes) 2759
# Outliers from Z-scores method of gaming_ul_(bytes) 2782
# Outliers from Z-scores method of other_dl_(bytes) 2825
# Outliers from Z-scores method of other_ul_(bytes) 2799
# Outliers from Z-scores method of total_ul_(bytes) 1471
# Outliers from Z-scores method of total_dl_(bytes) 1251

# %% [markdown]
# Data needs further preprocessing as there are some outliers in the data

# %%
outlier_columns = []
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df[col])
    if len(sample_outliers) > 0:
        outlier_columns.append(col)

# %%
len(outlier_columns)
# Out:
# 29

# %%
df_cop = df.copy()

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

# generate 1000 data points randomly drawn from an exponential distribution
scaled_data = df.copy()

scaled_data.sample(5)
# Out:
#           bearer_id            start  start_ms              end  end_ms  \
# 63399  7.349883e+18   4/26/2019 6:32     441.0  4/27/2019 18:47   410.0
# 28283  1.311448e+19   4/24/2019 7:26     726.0   4/26/2019 8:48   942.0
# 48542  1.311448e+19   4/25/2019 7:39      69.0   4/26/2019 8:56   437.0
# 84111  1.311448e+19  4/27/2019 10:51     982.0   4/28/2019 0:20   153.0
# 79698  6.917538e+18   4/27/2019 7:31      29.0   4/28/2019 4:06   542.0
#
#        dur._(ms)          imsi  msisdn/number          imei  \
# 63399  11.778998  2.082017e+14   3.366030e+10  3.553781e+13
# 28283  12.087886  2.082010e+14   3.366975e+10  3.570111e+13
# 48542  11.418736  2.082014e+14   3.367587e+10  3.589521e+13
# 84111  10.790823  2.082014e+14   3.376069e+10  8.699070e+13
# 79698  11.213468  2.082014e+14   3.366817e+10  3.537281e+13
#
#       last_location_name  ...  youtube_dl_(bytes)  youtube_ul_(bytes)  \
# 63399            T19259A  ...           15.730680           16.202195
# 28283            D79670A  ...           15.868884           16.486418
# 48542            D73566C  ...           16.924250           16.004911
# 84111            T21469A  ...           14.679575           16.336049
# 79698            G15735A  ...           14.199800           16.824948
#
#        netflix_dl_(bytes)  netflix_ul_(bytes)  gaming_dl_(bytes)  \
# 63399           15.576845           16.421906          20.346745
# 28283           16.549086           15.978441          20.304320
# 48542           15.274156           15.638189          20.397777
# 84111           15.948703           16.664682          20.275437
# 79698           16.029245           16.594183          18.903097
#
#        gaming_ul_(bytes)  other_dl_(bytes)  other_ul_(bytes)  \
# 63399          13.684214         20.235109         16.335324
# 28283          16.285959         20.480384         16.240899
# 48542          13.656034         20.303297         15.406344
# 84111          16.423921         15.205715         15.940235
# 79698          13.348396         20.340864         16.217038
#
#        total_ul_(bytes)  total_dl_(bytes)
# 63399         17.536929         20.367902
# 28283         17.678603         20.346945
# 48542         16.991387         20.453581
# 84111         17.789584         20.316098
# 79698         17.725386         18.989811
#
# [5 rows x 55 columns]

# %%
df_cop[outlier_columns].shape #= scaled_data
scaled_data.shape
# Out:
# (150001, 55)

# %%
scaled_data = minmax_scaler.fit_transform(scaled_data[outlier_columns])

# %%
scaled_data.shape
# Out:
# (150001, 29)

# %%
outlier_columns = []
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df_cop[col])
    if len(sample_outliers) > 0:
        outlier_columns.append(col)
# Out:
# /Users/basilel/Documents/Telecom-Data-Analysis/src/outlier.py:51: RuntimeWarning: invalid value encountered in scalar subtract
#   z_score = (i-mean)/std

# %%
len(outlier_columns)
# Out:
# 29

# %%
# outliers_dict = outlier.calculate_num_outliers_zscore(df, num_cols)
for col in num_cols:
    sample_outliers = outlier.calculate_num_outliers_zscore(df_cop[col])
    print(f"Outliers from Z-scores method of {col}", len(sample_outliers))
# Out:
# Outliers from Z-scores method of dur._(ms) 500
# Outliers from Z-scores method of avg_rtt_dl_(ms) 0
# Outliers from Z-scores method of avg_rtt_ul_(ms) 0
# Outliers from Z-scores method of avg_bearer_tp_dl_(kbps) 0
# Outliers from Z-scores method of avg_bearer_tp_ul_(kbps) 0
# Outliers from Z-scores method of tcp_dl_retrans._vol_(bytes) 3049
# Outliers from Z-scores method of tcp_ul_retrans._vol_(bytes) 3857
# Outliers from Z-scores method of dl_tp_<_50_kbps_(%) 0
# Outliers from Z-scores method of 50_kbps_<_dl_tp_<_250_kbps_(%) 0
# Outliers from Z-scores method of 250_kbps_<_dl_tp_<_1_mbps_(%) 0
# Outliers from Z-scores method of dl_tp_>_1_mbps_(%) 0
# Outliers from Z-scores method of ul_tp_<_10_kbps_(%) 0
# Outliers from Z-scores method of 10_kbps_<_ul_tp_<_50_kbps_(%) 0
# Outliers from Z-scores method of 50_kbps_<_ul_tp_<_300_kbps_(%) 0
# Outliers from Z-scores method of ul_tp_>_300_kbps_(%) 0
# Outliers from Z-scores method of http_dl_(bytes) 2530
# Outliers from Z-scores method of http_ul_(bytes) 2171
# Outliers from Z-scores method of activity_duration_dl_(ms) 0
# Outliers from Z-scores method of activity_duration_ul_(ms) 0
# Outliers from Z-scores method of dur._(ms).1 500
# Outliers from Z-scores method of nb_of_sec_with_125000b_<_vol_dl 3115
# Outliers from Z-scores method of nb_of_sec_with_1250b_<_vol_ul_<_6250b 5119
# Outliers from Z-scores method of nb_of_sec_with_31250b_<_vol_dl_<_125000b 4372
# Outliers from Z-scores method of nb_of_sec_with_37500b_<_vol_ul 6618
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_dl_<_31250b 4048
# Outliers from Z-scores method of nb_of_sec_with_6250b_<_vol_ul_<_37500b 3354
# Outliers from Z-scores method of nb_of_sec_with_vol_dl_<_6250b 3
# Outliers from Z-scores method of nb_of_sec_with_vol_ul_<_1250b 6
# Outliers from Z-scores method of social_media_dl_(bytes) 2752
# Outliers from Z-scores method of social_media_ul_(bytes) 0
# Outliers from Z-scores method of google_dl_(bytes) 2811
# Outliers from Z-scores method of google_ul_(bytes) 2766
# Outliers from Z-scores method of email_dl_(bytes) 2740
# Outliers from Z-scores method of email_ul_(bytes) 2728
# Outliers from Z-scores method of youtube_dl_(bytes) 2750
# Outliers from Z-scores method of youtube_ul_(bytes) 2808
# Outliers from Z-scores method of netflix_dl_(bytes) 2767
# Outliers from Z-scores method of netflix_ul_(bytes) 2755
# Outliers from Z-scores method of gaming_dl_(bytes) 2759
# Outliers from Z-scores method of gaming_ul_(bytes) 2782
# Outliers from Z-scores method of other_dl_(bytes) 2825
# Outliers from Z-scores method of other_ul_(bytes) 2799
# Outliers from Z-scores method of total_ul_(bytes) 1471
# Outliers from Z-scores method of total_dl_(bytes) 1251

# %%
df_cop[num_cols].boxplot()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# <Axes: >

# %% [markdown]
# Most of the outliers have been handled

# %%
pl.plot_box(df_cop, 'dur._(ms)', 'Total Duration of the xDR (in ms) after outlier handling')

# %%
df_cop.describe()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           bearer_id       start_ms         end_ms      dur._(ms)  \
# count  1.500010e+05  150001.000000  150001.000000  150001.000000
# mean   1.012045e+19     499.188199     498.800888      11.315589
# std    2.892438e+18     288.610872     288.096693       0.728958
# min    6.917538e+18       0.000000       0.000000       8.873748
# 25%    7.349883e+18     250.000000     251.000000      10.958531
# 50%    7.349883e+18     499.000000     500.000000      11.366731
# 75%    1.304243e+19     749.000000     750.000000      11.793809
# max    1.318654e+19     999.000000     999.000000      14.435730
#
#                imsi  msisdn/number          imei  avg_rtt_dl_(ms)  \
# count  1.500010e+05   1.500010e+05  1.500010e+05     1.500010e+05
# mean   2.082016e+14   4.182441e+10  4.842592e+13             -inf
# std    2.144723e+10   2.438731e+12  2.238739e+13              NaN
# min    2.040471e+14   3.360100e+10  4.400152e+11             -inf
# 25%    2.082014e+14   3.365151e+10  3.546261e+13     3.555348e+00
# 50%    2.082015e+14   3.366371e+10  3.572201e+13     3.806662e+00
# 75%    2.082018e+14   3.368307e+10  8.611970e+13     4.127134e+00
# max    2.140743e+14   8.823971e+14  9.900120e+13     1.148167e+01
#
#        avg_rtt_ul_(ms)  avg_bearer_tp_dl_(kbps)  ...  youtube_dl_(bytes)  \
# count     1.500010e+05             1.500010e+05  ...       150001.000000
# mean              -inf                     -inf  ...           15.963339
# std                NaN                      NaN  ...            0.999826
# min               -inf                     -inf  ...            3.970292
# 25%       1.098612e+00             3.761200e+00  ...           15.579128
# 50%       1.609438e+00             4.143135e+00  ...           16.267896
# 75%       2.397895e+00             9.888881e+00  ...           16.674765
# max       8.870663e+00             1.284307e+01  ...           16.962207
#
#        youtube_ul_(bytes)  netflix_dl_(bytes)  netflix_ul_(bytes)  \
# count       150001.000000       150001.000000       150001.000000
# mean            15.907689           15.960316           15.905965
# std              1.001628            1.002698            1.001366
# min              4.653960            3.737670            3.555348
# 25%             15.523520           15.569422           15.515882
# 50%             16.214628           16.270148           16.213077
# 75%             16.619814           16.676023           16.619311
# max             16.907097           16.962211           16.907096
#
#        gaming_dl_(bytes)  gaming_ul_(bytes)  other_dl_(bytes)  \
# count      150001.000000      150001.000000     150001.000000
# mean           19.552311          15.623673         19.550172
# std             1.001953           1.000328          1.004539
# min             7.830426           4.077537          8.098643
# 25%            19.164869          15.233419         19.163508
# 50%            19.863847          15.930706         19.860049
# 75%            20.266256          16.335754         20.263912
# max            20.553002          16.622428         20.553002
#
#        other_ul_(bytes)  total_ul_(bytes)  total_dl_(bytes)
# count     150001.000000     150001.000000     150001.000000
# mean          15.619125         17.489536         19.716029
# std            1.006696          0.304412          0.760145
# min            4.997212         14.868739         15.777581
# 25%           15.237641         17.318724         19.309013
# 50%           15.927791         17.532572         19.937655
# 75%           16.331928         17.708029         20.316357
# max           16.622429         18.176458         20.621199
#
# [8 rows x 50 columns]

# %% [markdown]
# Save the data

# %%
df_cop.to_csv('../data/cleaned_data_outliers.csv', index=False)
